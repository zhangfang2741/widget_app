# %%
import yfinance as yf

# 以标普500 ETF (VOO) 为例
voo = yf.Ticker("VOO")
news = voo.news
for item in news:
    print(f"标题: {item['title']}\n来源: {item['publisher']}\n链接: {item['link']}\n")
# Out:
# ---------------------------------------------------------------------------
# YFRateLimitError                          Traceback (most recent call last)
# Cell In[1], line 5
#       3 # 以标普500 ETF (VOO) 为例
#       4 voo = yf.Ticker("VOO")
# ----> 5 news = voo.news
#       6 for item in news:
#       7     print(f"标题: {item['title']}\n来源: {item['publisher']}\n链接: {item['link']}\n")
#
# File ~/PycharmProjects/widget_app/.venv/lib/python3.12/site-packages/yfinance/ticker.py:312, in Ticker.news(self)
#     310 @property
#     311 def news(self) -> list:
# --> 312     return self.get_news()
#
# File ~/PycharmProjects/widget_app/.venv/lib/python3.12/site-packages/yfinance/base.py:596, in TickerBase.get_news(self, count, tab)
#     588 url = f"{_ROOT_URL_}/xhr/ncp?queryRef={query_ref}&serviceKey=ncp_fin"
#     589 payload = {
#     590     "serviceConfig": {
#     591         "snippetCount": count,
#     592         "s": [self.ticker]
#     593     }
#     594 }
# ...
